# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("A:\Dataset\EdStatsData.csv\EdStatsData.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\1563728278.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("A:\Dataset\EdStatsData.csv\EdStatsData.csv")
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
df.drop(['Unnamed: 69'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 69 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
#                    ...
# 2080              835494
# 2085              835494
# 2090              835494
# 2095              835494
# 2100              835494
# Length: 69, dtype: int64

# %%
df.isna()
# Out:
#         Country Name  Country Code  Indicator Name  Indicator Code   1970  \
# 0              False         False           False           False   True
# 1              False         False           False           False   True
# 2              False         False           False           False   True
# 3              False         False           False           False   True
# 4              False         False           False           False  False
# ...              ...           ...             ...             ...    ...
# 886925         False         False           False           False   True
# 886926         False         False           False           False   True
# 886927         False         False           False           False   True
# 886928         False         False           False           False   True
# 886929         False         False           False           False   True
#
#          1971   1972   1973   1974   1975  ...  2055  2060  2065  2070  2075  \
# ...

# %%
df.describe()
# Out:
#                1970          1971          1972          1973          1974  \
# count  7.228800e+04  3.553700e+04  3.561900e+04  3.554500e+04  3.573000e+04
# mean   1.974772e+09  4.253638e+09  4.592365e+09  5.105006e+09  5.401493e+09
# std    1.211687e+11  1.804814e+11  1.914083e+11  2.059170e+11  2.112150e+11
# min   -1.435564e+00 -1.594625e+00 -3.056522e+00 -4.032582e+00 -4.213563e+00
# 25%    8.900000e-01  8.853210e+00  9.240920e+00  9.595200e+00  9.861595e+00
# 50%    6.317724e+00  6.316240e+01  6.655139e+01  6.969595e+01  7.087760e+01
# 75%    6.251250e+01  5.655200e+04  5.863650e+04  6.202900e+04  6.383675e+04
# max    1.903929e+13  1.986457e+13  2.100916e+13  2.238367e+13  2.282991e+13
#
#                1975          1976          1977          1978          1979  \
# count  8.730600e+04  3.748300e+04  3.757400e+04  3.757600e+04  3.680900e+04
# mean   2.314288e+09  5.731808e+09  6.124437e+09  6.671489e+09  7.436724e+09
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100'],
#       dtype='object')

# %%
df['1971'].fillna(df['1971'].median(skipna=True),inplace=True)
df['1972'].fillna(df['1972'].median(skipna=True),inplace=True)
df['1973'].fillna(df['1973'].median(skipna=True),inplace=True)
df['1974'].fillna(df['1974'].median(skipna=True),inplace=True)
df['1975'].fillna(df['1975'].median(skipna=True),inplace=True)
df['1976'].fillna(df['1976'].median(skipna=True),inplace=True)
df['1977'].fillna(df['1977'].median(skipna=True),inplace=True)
df['1978'].fillna(df['1978'].median(skipna=True),inplace=True)
df['1979'].fillna(df['1979'].median(skipna=True),inplace=True)
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\367642520.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['1971'].fillna(df['1971'].median(skipna=True),inplace=True)
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\367642520.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
#                    ...
# 2080              835494
# 2085              835494
# 2090              835494
# 2095              835494
# 2100              835494
# Length: 69, dtype: int64

# %%
df['1980'].fillna(df['1980'].median(skipna=True),inplace=True)
df['1981'].fillna(df['1981'].median(skipna=True),inplace=True)
df['1982'].fillna(df['1982'].median(skipna=True),inplace=True)
df['1983'].fillna(df['1983'].median(skipna=True),inplace=True)
df['1984'].fillna(df['1984'].median(skipna=True),inplace=True)
df['1985'].fillna(df['1985'].median(skipna=True),inplace=True)
df['1987'].fillna(df['1987'].median(skipna=True),inplace=True)
df['1988'].fillna(df['1988'].median(skipna=True),inplace=True)
df['1989'].fillna(df['1989'].median(skipna=True),inplace=True)
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\4258908641.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['1980'].fillna(df['1980'].median(skipna=True),inplace=True)
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\4258908641.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['1990'].fillna(df['1991'].median(skipna=True),inplace=True)
df['1991'].fillna(df['1992'].median(skipna=True),inplace=True)
df['1992'].fillna(df['1993'].median(skipna=True),inplace=True)
df['1993'].fillna(df['1994'].median(skipna=True),inplace=True)
df['1994'].fillna(df['1995'].median(skipna=True),inplace=True)
df['1995'].fillna(df['1996'].median(skipna=True),inplace=True)
df['1996'].fillna(df['1997'].median(skipna=True),inplace=True)
df['1997'].fillna(df['1998'].median(skipna=True),inplace=True)
df['1998'].fillna(df['1999'].median(skipna=True),inplace=True)
df['1999'].fillna(df['2000'].median(skipna=True),inplace=True)
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\3025220614.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['1990'].fillna(df['1991'].median(skipna=True),inplace=True)
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\3025220614.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of         Country Name  Country Code  Indicator Name  Indicator Code   1970  \
# 0              False         False           False           False   True
# 1              False         False           False           False   True
# 2              False         False           False           False   True
# 3              False         False           False           False   True
# 4              False         False           False           False  False
# ...              ...           ...             ...             ...    ...
# 886925         False         False           False           False   True
# 886926         False         False           False           False   True
# 886927         False         False           False           False   True
# 886928         False         False           False           False   True
# 886929         False         False           False           False   True
#
# ...

# %%
df.isna().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
#                    ...
# 2080              835494
# 2085              835494
# 2090              835494
# 2095              835494
# 2100              835494
# Length: 69, dtype: int64

# %%
df
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# 3       Adjusted net enrolment rate, lower secondary, ...
# 4       Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# ...

# %%
df['2001'].fillna(df['2002'].median(skipna=True),inplace=True)
df['2002'].fillna(df['2003'].median(skipna=True),inplace=True)
df['2003'].fillna(df['2004'].median(skipna=True),inplace=True)
df['2004'].fillna(df['2005'].median(skipna=True),inplace=True)
df['2005'].fillna(df['2006'].median(skipna=True),inplace=True)
df['2006'].fillna(df['2007'].median(skipna=True),inplace=True)
df['2007'].fillna(df['2008'].median(skipna=True),inplace=True)
df['2008'].fillna(df['2009'].median(skipna=True),inplace=True)
df['2009'].fillna(df['2010'].median(skipna=True),inplace=True)
df['2010'].fillna(df['2011'].median(skipna=True),inplace=True)
df['2011'].fillna(df['2012'].median(skipna=True),inplace=True)
df['2012'].fillna(df['2013'].median(skipna=True),inplace=True)
df['2013'].fillna(df['2014'].median(skipna=True),inplace=True)
df['2014'].fillna(df['2015'].median(skipna=True),inplace=True)
df['2015'].fillna(df['2016'].median(skipna=True),inplace=True)
df['2016'].fillna(df['2017'].median(skipna=True),inplace=True)
df['2017'].fillna(df['2020'].median(skipna=True),inplace=True)
df['2020'].fillna(df['2025'].median(skipna=True),inplace=True)
df['2025'].fillna(df['2030'].median(skipna=True),inplace=True)
df['2030'].fillna(df['2035'].median(skipna=True),inplace=True)
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\3592030557.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['2001'].fillna(df['2002'].median(skipna=True),inplace=True)
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\3592030557.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['2035'].fillna(df['2040'].median(skipna=True),inplace=True)
df['2040'].fillna(df['2045'].median(skipna=True),inplace=True)
df['2045'].fillna(df['2050'].median(skipna=True),inplace=True)
df['2050'].fillna(df['2055'].median(skipna=True),inplace=True)
df['2055'].fillna(df['2060'].median(skipna=True),inplace=True)
df['2060'].fillna(df['2065'].median(skipna=True),inplace=True)
df['2065'].fillna(df['2070'].median(skipna=True),inplace=True)
df['2070'].fillna(df['2075'].median(skipna=True),inplace=True)
df['2075'].fillna(df['2080'].median(skipna=True),inplace=True)
df['2080'].fillna(df['2085'].median(skipna=True),inplace=True)
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\3187999147.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['2035'].fillna(df['2040'].median(skipna=True),inplace=True)
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\3187999147.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
#                    ...
# 2080                   0
# 2085              835494
# 2090              835494
# 2095              835494
# 2100              835494
# Length: 69, dtype: int64

# %%
df['2085'].fillna(df['2090'].median(skipna=True),inplace=True)
df['2090'].fillna(df['2095'].median(skipna=True),inplace=True)
df['2095'].fillna(df['2100'].median(skipna=True),inplace=True)
df['2100'].fillna(df['2100'].median(skipna=True),inplace=True)
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\4262308744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['2085'].fillna(df['2090'].median(skipna=True),inplace=True)
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\4262308744.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0       Adjusted net enrolment rate, lower secondary, ...
# 1       Adjusted net enrolment rate, lower secondary, ...
# 2       Adjusted net enrolment rate, lower secondary, ...
# 3       Adjusted net enrolment rate, lower secondary, ...
# 4       Adjusted net enrolment rate, primary, both sex...
# ...                                                   ...
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# ...

# %%
df['1970'].fillna(df['1970'].median(skipna=True),inplace=True)
df.isna().sum()
# Out:
# C:\Users\astik\AppData\Local\Temp\ipykernel_5868\2187536939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['1970'].fillna(df['1970'].median(skipna=True),inplace=True)
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1970              0
#                  ..
# 2080              0
# 2085              0
# 2090              0
# 2095              0
# 2100              0
# Length: 69, dtype: int64

# %%
df.shape
# Out:
# (886930, 69)

# %%
df.drop(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],axis=1,inplace=True)

# %%
df
# Out:
#              1970       1971       1972       1973       1974      1975  \
# 0        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 1        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 2        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 3        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 4       54.822121  54.894138  56.209438  57.267109  57.991138  59.36554
# ...           ...        ...        ...        ...        ...       ...
# 886925   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886926   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886927   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886928   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886929   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
#
#              1976       1977       1978       1979  ...  2055  2060  2065  \
# ...

# %%
X=df.iloc[:,:1].values
y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
# array([[6.3177236 ],
#        [6.3177236 ],
#        [6.3177236 ],
#        ...,
#        [7.42993021],
#        [6.3177236 ],
#        [6.3177236 ]])

# %%
X_test
# Out:
# array([[6.3177236],
#        [6.3177236],
#        [6.3177236],
#        ...,
#        [6.3177236],
#        [6.3177236],
#        [6.3177236]])

# %%
y_train
# Out:
# array([63.16239929, 63.16239929, 63.16239929, ...,  8.74738979,
#        63.16239929, 63.16239929])

# %%
y_test
# Out:
# array([63.16239929, 63.16239929, 63.16239929, ..., 63.16239929,
#        63.16239929, 63.16239929])

# %%
sns.scatterplot(x='2016',y='2017',data=df)
# Out:
# <Axes: xlabel='2016', ylabel='2017'>

# %%
sns.scatterplot(x='1970',y='1980',data=df)
# Out:
# <Axes: xlabel='1970', ylabel='1980'>

# %%
sns.scatterplot(x='1990',y='2000',data=df)
# Out:
# <Axes: xlabel='1990', ylabel='2000'>

# %%
sns.scatterplot(x='2000',y='2010',data=df)
# Out:
# <Axes: xlabel='2000', ylabel='2010'>

# %%
sns.scatterplot(x='2020',y='2030',data=df)
# Out:
# <Axes: xlabel='2020', ylabel='2030'>

# %%
sns.scatterplot(x='2040',y='2050',data=df)
# Out:
# <Axes: xlabel='2040', ylabel='2050'>

# %%
sns.scatterplot(x='2060',y='2070',data=df)
# Out:
# <Axes: xlabel='2060', ylabel='2070'>

# %%
sns.scatterplot(x='2080',y='2090',data=df)
# Out:
# <Axes: xlabel='2080', ylabel='2090'>

# %%
sns.scatterplot(x='1975',y='1985',data=df)
# Out:
# <Axes: xlabel='1975', ylabel='1985'>

# %%
sns.scatterplot(x='1995',y='2005',data=df)
# Out:
# <Axes: xlabel='1995', ylabel='2005'>

# %%
sns.scatterplot(x='2015',y='2025',data=df)
# Out:
# <Axes: xlabel='2015', ylabel='2025'>

# %%
sns.scatterplot(x='2035',y='2045',data=df)
# Out:
# <Axes: xlabel='2035', ylabel='2045'>

# %%
sns.scatterplot(x='2055',y='2065',data=df)
# Out:
# <Axes: xlabel='2055', ylabel='2065'>

# %%
sns.scatterplot(x='2075',y='2085',data=df)
# Out:
# <Axes: xlabel='2075', ylabel='2085'>

# %%
sns.scatterplot(x='2095',y='2100',data=df)
# Out:
# <Axes: xlabel='2095', ylabel='2100'>

# %%
sns.scatterplot(x='1970',y='2000',data=df)
# Out:
# <Axes: xlabel='1970', ylabel='2000'>

# %%
sns.scatterplot(x='2000',y='2030',data=df)
# Out:
# <Axes: xlabel='2000', ylabel='2030'>

# %%
sns.scatterplot(x='2030',y='2060',data=df)
# Out:
# <Axes: xlabel='2030', ylabel='2060'>

# %%
sns.scatterplot(x='2060',y='2090',data=df)
# Out:
# <Axes: xlabel='2060', ylabel='2090'>

# %%
sns.scatterplot(x='2090',y='2100',data=df)
# Out:
# <Axes: xlabel='2090', ylabel='2100'>

# %%
sns.scatterplot(x='1970',y='2070',data=df)
# Out:
# <Axes: xlabel='1970', ylabel='2070'>

# %%
sns.scatterplot(x='2000',y='2100',data=df)
# Out:
# <Axes: xlabel='2000', ylabel='2100'>

# %%
sns.scatterplot(x='1995',y='2095',data=df)
# Out:
# <Axes: xlabel='1995', ylabel='2095'>

# %%
sns.scatterplot(x='1975',y='2075',data=df)
# Out:
# <Axes: xlabel='1975', ylabel='2075'>

# %%
sns.scatterplot(x='1985',y='2085',data=df)
# Out:
# <Axes: xlabel='1985', ylabel='2085'>

# %% [markdown]
# In first case,the data is accumulated in differed points at most places in 0.0 to 1.0 in both axis and then splitted in the year of 1985 & 2085,2015 & 2025,1975 & 2075.

# %% [markdown]
# In second case,the data is divided into a straight line at 2000 to 2100 and the whole data points is splitted at point 0.22 of the year 2000 & 2100,2000 & 2030.

# %% [markdown]
# In third case,the data is adjusted at 0.0 & 0.5 and then it is splitted into other places of the point graph in the year 2030 & 2060,2060 & 2090,2090 & 2100.

# %% [markdown]
# In fourth case, the data points is showed in the points of 0 & 1 and are divided into 0.2,0.25,0.5,1 also in the year 1970 & 2000,2030 & 2060,2060 & 2090.

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
plt.scatter(X_train,y_train,color='blue')
plt.plot(X_train,model.predict(X_train),color='red')
plt.show()

# %%
plt.scatter(X_test,y_test,color='blue')
plt.plot(X_test,model.predict(X_test),color='red')
plt.show()

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.NaN,strategy='mean')
imputer.fit(X[:,:1])
X[:,:1]=imputer.transform(X[:,:1])

# %%
df
# Out:
#              1970       1971       1972       1973       1974      1975  \
# 0        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 1        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 2        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 3        6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 4       54.822121  54.894138  56.209438  57.267109  57.991138  59.36554
# ...           ...        ...        ...        ...        ...       ...
# 886925   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886926   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886927   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886928   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
# 886929   6.317724  63.162399  66.551392  69.695953  70.877602   9.67742
#
#              1976       1977       1978       1979  ...  2055  2060  2065  \
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
col_tf=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0]),],remainder='passthrough')
X=np.array(col_tf.fit_transform(X))

# %%
print(X)
# Out:
#   (0, 2801)	1.0
#   (1, 2801)	1.0
#   (2, 2801)	1.0
#   (3, 2801)	1.0
#   (4, 9716)	1.0
#   (5, 8010)	1.0
#   (6, 594)	1.0
#   (7, 10527)	1.0
#   (8, 2801)	1.0
#   (9, 2801)	1.0
#   (10, 2801)	1.0
#   (11, 2801)	1.0
#   (12, 9459)	1.0
#   (13, 8132)	1.0
#   (14, 691)	1.0
#   (15, 10124)	1.0
#   (16, 2801)	1.0
#   (17, 2801)	1.0
#   (18, 2801)	1.0
#   (19, 2801)	1.0
#   (20, 2801)	1.0
#   (21, 2801)	1.0
#   (22, 2801)	1.0
#   (23, 2801)	1.0
#   (24, 2801)	1.0
#   :	:
#   (886905, 2801)	1.0
#   (886906, 2801)	1.0
#   (886907, 2801)	1.0
#   (886908, 2801)	1.0
#   (886909, 2801)	1.0
#   (886910, 2801)	1.0
#   (886911, 2801)	1.0
#   (886912, 2801)	1.0
#   (886913, 2801)	1.0
#   (886914, 2801)	1.0
#   (886915, 2801)	1.0
#   (886916, 2801)	1.0
#   (886917, 2801)	1.0
#   (886918, 2801)	1.0
#   (886919, 2801)	1.0
#   (886920, 2801)	1.0
#   (886921, 2801)	1.0
#   (886922, 2801)	1.0
#   (886923, 2801)	1.0
#   (886924, 2801)	1.0
#   (886925, 2801)	1.0
#   (886926, 2801)	1.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
Y=le.fit_transform(y)

# %%
print(Y)
# Out:
# [14083 14083 14083 ... 14083 14083 14083]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.0047082]
#  [-0.0047082]
#  [-0.0047082]
#  ...
#  [-0.0047082]
#  [-0.0047082]
#  [-0.0047082]]

# %%
print(X_test)
# Out:
# [[-0.0047082]
#  [-0.0047082]
#  [-0.0047082]
#  ...
#  [-0.0047082]
#  [-0.0047082]
#  [-0.0047082]]

# %%
y_pred=model.predict(X_test)
np.set_printoptions(precision=2)

# %%
y_test
# Out:
# array([63.16, 63.16, 63.16, ..., 63.16, 63.16, 63.16])

# %%
y_pred
# Out:
# array([2363749.27, 2363749.27, 2363749.27, ..., 2363749.27, 2363749.27,
#        2363749.27])

# %%
plt.figure(figsize=(9,2))
plt.scatter(y_test,y_pred,color='blue',alpha=0.1)
plt.plot([min(y_test),max(y_test)],color='red',linestyle='--')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures(degree=2)
X_poly=pf.fit_transform(X_train)
poly_reg=LinearRegression()
poly_reg.fit(X_poly,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,y_train,color='blue')
plt.plot(X_train,lin_reg.predict(X_train),color='red')
plt.show()

# %%
plt.scatter(X_test,y_test,color='blue')
plt.plot(X_test,lin_reg.predict(X_test),color='red')
plt.show()

# %%
plt.scatter(X_train,y_train,color='blue')
plt.plot(X_train,poly_reg.predict(X_poly),color='red')
plt.show()

# %%
lin_reg.predict([[6.5]])
# Out:
# array([2.04e+11])

# %%
lin_reg.predict([[5.6]])
# Out:
# array([1.76e+11])

# %%
poly_reg.predict(pf.fit_transform([[6.6]]))
# Out:
# array([2.13e+11])

# %%
poly_reg.predict(pf.fit_transform([[5.5]]))
# Out:
# array([1.77e+11])

# %% [markdown]
# In linear regression,the data points are not perfectly fitted but in polynomial regression,the data points are perfectly fitted.
