# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("A:\Dataset\Position_Salaries.csv")
dataset
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\astik\AppData\Local\Temp\ipykernel_15356\3266063270.py:1: SyntaxWarning: invalid escape sequence '\D'
#   dataset=pd.read_csv("A:\Dataset\Position_Salaries.csv")
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
X=dataset.iloc[:,1:2].values
y=dataset.iloc[:,2].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
def viz_lin():
    plt.scatter(X,y,color='red')
    plt.plot(X,lin_reg.predict(X),color='blue')
    plt.title('Linear Regression Model')
    plt.xlabel('Position')
    plt.ylabel('Salary')
    plt.show()
    return

# %%
viz_lin()

# %% [markdown]
# Fitting a regression line based on salary and position

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=4)
X_poly=poly_reg.fit_transform(X)
pol_reg=LinearRegression()
pol_reg.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
def viz_poly():
    plt.scatter(X,y,color='red')
    plt.plot(X,pol_reg.predict(poly_reg.fit_transform(X)),color='blue')
    plt.title('Polynomial Regression model')
    plt.xlabel('Position')
    plt.ylabel('Salary')
    plt.show()
    return

# %%
viz_poly()

# %%
lin_reg.predict([[5]])
# Out:
# array([209060.60606061])

# %%
lin_reg.predict([[6,]])
# Out:
# array([289939.39393939])

# %%
pol_reg.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# array([132148.43750003])

# %%
pol_reg.predict(poly_reg.fit_transform([[6.6]]))
# Out:
# array([162939.8974359])

# %%
pol_reg.predict(poly_reg.fit_transform([[5]]))
# Out:
# array([121724.94172498])

# %%
pol_reg.predict(poly_reg.fit_transform([[6,]]))
# Out:
# array([143275.05827508])

# %%
lin_reg.predict([[6.6]])
# Out:
# array([338466.66666667])

# %%
lin_reg.predict([[5.5]])
# Out:
# array([249500.])

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000>

# %%
sns.barplot(x='Level',y='Salary',data=dataset)
# Out:
# <Axes: xlabel='Level', ylabel='Salary'>

# %%
sns.scatterplot(x='Level',y='Salary',data=dataset)
# Out:
# <Axes: xlabel='Level', ylabel='Salary'>

# %% [markdown]
# As this graph shown that Business Analyst has lower level of salary and CEO has higher level of salary.
